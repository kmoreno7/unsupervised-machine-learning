# %%
#Import libraries
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#Turn csv into a pandas dataframe
file = "myopia.csv"

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
#drop the MYOPIC column
df2=df.drop(columns=["MYOPIC"])
df2.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0        0    10         34      1      1
# 1        1     7         12      1      1
# 2        0    10         14      0      0
# 3        0     4         37      0      1
# 4        0     4          4      1      0

# %%
# Standarize data with StandarScaler
df_scaled = StandardScaler().fit_transform(df2)

# %%
# Initialize PCA model
pca = PCA(n_components=.90)

# Get 90% principal components for the scaled data.
df_scaled_pca = pca.fit_transform(df_scaled)

df_scaled_pca
# Out:
# array([[ 5.35502713e-01,  1.14500427e+00, -1.38501894e+00, ...,
#         -1.92299652e+00,  2.67528503e-02,  1.78143856e-01],
#        [-6.24705593e-01, -1.57578643e+00, -7.94253057e-01, ...,
#          2.85332291e-01,  6.89682613e-01, -5.57030831e-01],
#        [-9.33479366e-01, -7.17076224e-01,  8.20149929e-01, ...,
#         -3.08170124e-02, -4.31499076e-01,  1.33358217e-02],
#        ...,
#        [-8.90082017e-01, -2.30800520e+00,  2.68101833e-01, ...,
#         -4.89876908e-01,  1.82269069e+00,  8.17765449e-02],
#        [-1.12399979e+00,  4.51889784e-01,  1.65865634e-03, ...,
#          2.39685015e-01, -1.59282241e+00, -1.01458084e+00],
#        [-6.91533913e-01, -7.37046188e-01, -1.05290000e+00, ...,
#         -2.73804495e-01,  9.46160724e-01,  4.95797353e-01]])

# %%
# Initialize t-SNE model
tsne = TSNE(learning_rate=35)
tsne_features = tsne.fit_transform(df_scaled_pca)
# Out:
# /Users/kevinmoreno/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
tsne_features.shape

# %%
# Prepare to plot the dataset

# The first column of transformed features
df2['x'] = tsne_features[:,0]

# The second column of transformed features
df2['y'] = tsne_features[:,1]

# %%
# Visualize the clusters
plt.scatter(df2['x'], df2['y'])
plt.show()

# %%
# Finding the best value for k
inertia = []
k = list(range(1, 10))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_scaled_pca)
    inertia.append(km.inertia_)

# Creating the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(list(range(11)))
plt.title('Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# It appears that the elbow of the plots is at 3.

# %%
# Based on the the k-means it appears that the data can be clustered into 3 groups
# Though no difinitive clusters were given by the t-SNE model.
